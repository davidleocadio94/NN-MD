# %%
import ModelClassForPrediction as Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %% [markdown]
# # 1x1x1

# %%
import ModelClassForPrediction as Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

E=[]
F=[]
R=[]
Z=[]
CELL=[]

r=[[ 3.89766467122725e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  3.89766548973703e+00]]

cell=[[ 3.89766560666700e+00,  0.00000000000000e+00,  0.00000000000000e+00],
     [ 0.00000000000000e+00,  3.89766560666700e+00,  0.00000000000000e+00],
     [ 0.00000000000000e+00,  0.00000000000000e+00,  3.89766560666700e+00]]
e=0
f=(np.array(r)*0).tolist()

z=[38,22,8,8,8]

E.append([e])
F.append(f)
R.append(r)
Z.append(z)
CELL.append(cell)

E=np.array(E)
F=np.array(F)
R=np.array(R)
z=np.array(z)
CELL=np.array(CELL)

np.savez('EquilibriumStructures/1x1x1',E=E,F=F,R=R,z=z,CELL=CELL)
data=np.load('EquilibriumStructures/1x1x1.npz')
data['CELL'][0]
# Out:
# array([[3.89766561, 0.        , 0.        ],
#        [0.        , 3.89766561, 0.        ],
#        [0.        , 0.        , 3.89766561]])

# %%
NN=Model.Model(PathToModel='nvt.1500.RS/',PathToData='EquilibriumStructures/1x1x1.npz',TestSetSize=1)

PredictedForces,PredictedEnergies,\
ActualForces,ActualEnergies \
=NN.PredictForcesAndEnergies()

plt.figure()
plt.plot(PredictedForces.flatten(),ActualForces.flatten()\
         ,'o',label='R2='+str(r2_score(ActualForces.flatten(),PredictedForces.flatten())))
plt.xlabel('predicted F (eV/Ang)')
plt.ylabel('actual F (eV/Ang)')
plt.legend()
# Out:
# /home/villarreal/Documents/STO_MD/STO120atomPlusData/STO120atomPlusData
# /home/villarreal/Documents/STO_MD/STO120atomPlusData/STO120atomPlusData/nvt.1500.RS/
# /home/villarreal/.local/lib/python3.8/site-packages/torch/serialization.py:587: UserWarning: 'torch.load' received a zip file that looks like a TorchScript archive dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to silence this warning)
#   warnings.warn("'torch.load' received a zip file that looks like a TorchScript archive"
# Running point 0

# %%
PredictedForces

# %% [markdown]
# # 2x2x2

# %%
import ModelClassForPrediction as Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score


E=[]
F=[]
R=[]
Z=[]

r= [[ 7.79533027789425e+00,  7.79532899166460e+00,  7.79533109640403e+00],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  7.79533109640403e+00],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  7.79533109640403e+00],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  7.79533109640403e+00],
     [ 7.79533027789425e+00,  7.79532899166460e+00,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 7.79533027789425e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 7.79533027789425e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 7.79533027789425e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 7.79533027789425e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 3.89766467122725e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  1.94883268640353e+00],
     [ 5.84649747456076e+00,  7.79532899166460e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 5.84649747456076e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  5.84649829307053e+00],
     [ 5.84649747456076e+00,  7.79532899166460e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  5.84649829307053e+00],
     [ 5.84649747456076e+00,  3.89766338499760e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  3.89766548973703e+00]]
e=0
f=(np.array(r)*0).tolist()

z='38 38 38 38 38 38 38 38 22 22 22 22 22 22 22 22  8  8  8  8  8  8  8  8 '+\
   '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8'

z = [int(i) for i in z.split()]

E.append([e])
F.append(f)
R.append(r)
Z.append(z)

E=np.array(E)
F=np.array(F)
R=np.array(R)
z=np.array(z)

np.savez('EquilibriumStructures/2x2x2',E=E,F=F,R=R,z=z)
#data=np.load('EquilibriumStructures/2x2x2.npz')

# %%
NN=Model.Model(PathToModel='nvt.1500.RS/',PathToData='EquilibriumStructures/2x2x2.npz',TestSetSize=1)

PredictedForces,PredictedEnergies,\
ActualForces,ActualEnergies \
=NN.PredictForcesAndEnergies()

plt.figure()
plt.plot(PredictedForces.flatten(),ActualForces.flatten()\
         ,'o',label='R2='+str(r2_score(ActualForces.flatten(),PredictedForces.flatten())))
plt.xlabel('predicted F (eV/Ang)')
plt.ylabel('actual F (eV/Ang)')
plt.legend()

# %% [markdown]
# # 3x3x3

# %%
import ModelClassForPrediction as Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score


E=[]
F=[]
R=[]
Z=[]

r=[[ 1.16929958845613e+01,  1.16929945983316e+01,  1.16929967030710e+01],
     [ 3.89766467122725e+00,  1.16929945983316e+01,  1.16929967030710e+01],
     [ 7.79533027789425e+00,  1.16929945983316e+01,  1.16929967030710e+01],
     [ 1.16929958845613e+01,  3.89766338499760e+00,  1.16929967030710e+01],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  1.16929967030710e+01],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  1.16929967030710e+01],
     [ 1.16929958845613e+01,  7.79532899166460e+00,  1.16929967030710e+01],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  1.16929967030710e+01],
     [ 7.79533027789425e+00,  7.79532899166460e+00,  1.16929967030710e+01],
     [ 1.16929958845613e+01,  1.16929945983316e+01,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  1.16929945983316e+01,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  1.16929945983316e+01,  3.89766548973703e+00],
     [ 1.16929958845613e+01,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 1.16929958845613e+01,  7.79532899166460e+00,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  7.79532899166460e+00,  3.89766548973703e+00],
     [ 1.16929958845613e+01,  1.16929945983316e+01,  7.79533109640403e+00],
     [ 3.89766467122725e+00,  1.16929945983316e+01,  7.79533109640403e+00],
     [ 7.79533027789425e+00,  1.16929945983316e+01,  7.79533109640403e+00],
     [ 1.16929958845613e+01,  3.89766338499760e+00,  7.79533109640403e+00],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  7.79533109640403e+00],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  7.79533109640403e+00],
     [ 1.16929958845613e+01,  7.79532899166460e+00,  7.79533109640403e+00],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  7.79533109640403e+00],
     [ 7.79533027789425e+00,  7.79532899166460e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 1.16929958845613e+01,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 7.79533027789425e+00,  1.94883058166410e+00,  1.94883268640353e+00],
     [ 1.16929958845613e+01,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 7.79533027789425e+00,  5.84649618833110e+00,  1.94883268640353e+00],
     [ 1.16929958845613e+01,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 3.89766467122725e+00,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 7.79533027789425e+00,  9.74416179499810e+00,  1.94883268640353e+00],
     [ 1.16929958845613e+01,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 7.79533027789425e+00,  1.94883058166410e+00,  5.84649829307053e+00],
     [ 1.16929958845613e+01,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 3.89766467122725e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 7.79533027789425e+00,  5.84649618833110e+00,  5.84649829307053e+00],
     [ 1.16929958845613e+01,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 3.89766467122725e+00,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 7.79533027789425e+00,  9.74416179499810e+00,  5.84649829307053e+00],
     [ 1.16929958845613e+01,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 3.89766467122725e+00,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 7.79533027789425e+00,  1.94883058166410e+00,  9.74416389973753e+00],
     [ 1.16929958845613e+01,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 3.89766467122725e+00,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 7.79533027789425e+00,  5.84649618833110e+00,  9.74416389973753e+00],
     [ 1.16929958845613e+01,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 3.89766467122725e+00,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 7.79533027789425e+00,  9.74416179499810e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  1.16929945983316e+01,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  1.16929945983316e+01,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  1.16929945983316e+01,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  3.89766338499760e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  1.94883268640353e+00],
     [ 5.84649747456075e+00,  7.79532899166460e+00,  1.94883268640353e+00],
     [ 9.74416308122775e+00,  7.79532899166460e+00,  1.94883268640353e+00],
     [ 1.94883186789375e+00,  1.16929945983316e+01,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  1.16929945983316e+01,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  1.16929945983316e+01,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  3.89766338499760e+00,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  3.89766338499760e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  5.84649829307053e+00],
     [ 5.84649747456075e+00,  7.79532899166460e+00,  5.84649829307053e+00],
     [ 9.74416308122775e+00,  7.79532899166460e+00,  5.84649829307053e+00],
     [ 1.94883186789375e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 5.84649747456075e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 9.74416308122775e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 5.84649747456075e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 9.74416308122775e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 5.84649747456075e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 9.74416308122775e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 5.84649747456075e+00,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 9.74416308122775e+00,  9.74416179499810e+00,  7.79533109640403e+00]]
e=0
f=(np.array(r)*0).tolist()

z='38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 '+\
 '38 38 38 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 '+\
 '22 22 22 22 22 22  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8'

z = [int(i) for i in z.split()]


E.append([e])
F.append(f)
R.append(r)
Z.append(z)

E=np.array(E)
F=np.array(F)
R=np.array(R)
z=np.array(z)

np.savez('EquilibriumStructures/3x3x3',E=E,F=F,R=R,z=z)
#data=np.load('EquilibriumStructures/3x3x3.npz')

# %%
NN=Model.Model(PathToModel='nvt.1500.RS/',PathToData='EquilibriumStructures/3x3x3.npz',TestSetSize=1)

PredictedForces,PredictedEnergies,\
ActualForces,ActualEnergies \
=NN.PredictForcesAndEnergies()

plt.figure()
plt.plot(PredictedForces.flatten(),ActualForces.flatten()\
         ,'o',label='R2='+str(r2_score(ActualForces.flatten(),PredictedForces.flatten())))
plt.xlabel('predicted F (eV/Ang)')
plt.ylabel('actual F (eV/Ang)')
plt.legend()

# %% [markdown]
# # 4x4x4

# %%
import ModelClassForPrediction as Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

E=[]
F=[]
R=[]
Z=[]

r=   [[ 1.55906614912283e+01,  1.55906602049986e+01,  1.55906623097380e+01],
     [ 3.89766467122725e+00,  1.55906602049986e+01,  1.55906623097380e+01],
     [ 7.79533027789425e+00,  1.55906602049986e+01,  1.55906623097380e+01],
     [ 1.16929958845613e+01,  1.55906602049986e+01,  1.55906623097380e+01],
     [ 1.55906614912283e+01,  3.89766338499760e+00,  1.55906623097380e+01],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  1.55906623097380e+01],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  1.55906623097380e+01],
     [ 1.16929958845613e+01,  3.89766338499760e+00,  1.55906623097380e+01],
     [ 1.55906614912283e+01,  7.79532899166460e+00,  1.55906623097380e+01],
     [ 3.89766467122725e+00,  7.79532899166460e+00,  1.55906623097380e+01],
     [ 7.79533027789425e+00,  7.79532899166460e+00,  1.55906623097380e+01],
     [ 1.16929958845613e+01,  7.79532899166460e+00,  1.55906623097380e+01],
     [ 1.55906614912283e+01,  1.16929945983316e+01,  1.55906623097380e+01],
     [ 3.89766467122725e+00,  1.16929945983316e+01,  1.55906623097380e+01],
     [ 7.79533027789425e+00,  1.16929945983316e+01,  1.55906623097380e+01],
     [ 1.16929958845613e+01,  1.16929945983316e+01,  1.55906623097380e+01],
     [ 1.55906614912283e+01,  1.55906602049986e+01,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  1.55906602049986e+01,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  1.55906602049986e+01,  3.89766548973703e+00],
     [ 1.16929958845613e+01,  1.55906602049986e+01,  3.89766548973703e+00],
     [ 1.55906614912283e+01,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 3.89766467122725e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 7.79533027789425e+00,  3.89766338499760e+00,  3.89766548973703e+00],
     [ 1.16929958845613e+01,  3.89766338499760e+00,
  9.74416389973753e+00],
     [ 5.84649747456076e+00,  1.55906602049986e+01,  9.74416389973753e+00],
     [ 9.74416308122776e+00,  1.55906602049986e+01,  9.74416389973753e+00],
     [ 1.36418286878948e+01,  1.55906602049986e+01,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 5.84649747456076e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 9.74416308122776e+00,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 1.36418286878948e+01,  3.89766338499760e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 5.84649747456076e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 9.74416308122776e+00,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 1.36418286878948e+01,  7.79532899166460e+00,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 5.84649747456076e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 9.74416308122776e+00,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 1.36418286878948e+01,  1.16929945983316e+01,  9.74416389973753e+00],
     [ 1.94883186789375e+00,  1.55906602049986e+01,  1.36418295064045e+01],
     [ 5.84649747456076e+00,  1.55906602049986e+01,  1.36418295064045e+01],
     [ 9.74416308122776e+00,  1.55906602049986e+01,  1.36418295064045e+01],
     [ 1.36418286878948e+01,  1.55906602049986e+01,  1.36418295064045e+01],
     [ 1.94883186789375e+00,  3.89766338499760e+00,  1.36418295064045e+01],
     [ 5.84649747456076e+00,  3.89766338499760e+00,  1.36418295064045e+01],
     [ 9.74416308122776e+00,  3.89766338499760e+00,  1.36418295064045e+01],
     [ 1.36418286878948e+01,  3.89766338499760e+00,  1.36418295064045e+01],
     [ 1.94883186789375e+00,  7.79532899166460e+00,  1.36418295064045e+01],
     [ 5.84649747456076e+00,  7.79532899166460e+00,  1.36418295064045e+01],
     [ 9.74416308122776e+00,  7.79532899166460e+00,  1.36418295064045e+01],
     [ 1.36418286878948e+01,  7.79532899166460e+00,  1.36418295064045e+01],
     [ 1.94883186789375e+00,  1.16929945983316e+01,  1.36418295064045e+01],
     [ 5.84649747456076e+00,  1.16929945983316e+01,  1.36418295064045e+01],
     [ 9.74416308122776e+00,  1.16929945983316e+01,  1.36418295064045e+01],
     [ 1.36418286878948e+01,  1.16929945983316e+01,  1.36418295064045e+01],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.55906623097380e+01],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  1.55906623097380e+01],
     [ 9.74416308122776e+00,  1.94883058166410e+00,  1.55906623097380e+01],
     [ 1.36418286878948e+01,  1.94883058166410e+00,  1.55906623097380e+01],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  1.55906623097380e+01],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  1.55906623097380e+01],
     [ 9.74416308122776e+00,  5.84649618833110e+00,  1.55906623097380e+01],
     [ 1.36418286878948e+01,  5.84649618833110e+00,  1.55906623097380e+01],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  1.55906623097380e+01],
     [ 5.84649747456076e+00,  9.74416179499810e+00,  1.55906623097380e+01],
     [ 9.74416308122776e+00,  9.74416179499810e+00,  1.55906623097380e+01],
     [ 1.36418286878948e+01,  9.74416179499810e+00,  1.55906623097380e+01],
     [ 1.94883186789375e+00,  1.36418274016651e+01,  1.55906623097380e+01],
     [ 5.84649747456076e+00,  1.36418274016651e+01,  1.55906623097380e+01],
     [ 9.74416308122776e+00,  1.36418274016651e+01,  1.55906623097380e+01],
     [ 1.36418286878948e+01,  1.36418274016651e+01,  1.55906623097380e+01],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 9.74416308122776e+00,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 1.36418286878948e+01,  1.94883058166410e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 9.74416308122776e+00,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 1.36418286878948e+01,  5.84649618833110e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 9.74416308122776e+00,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 1.36418286878948e+01,  9.74416179499810e+00,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  1.36418274016651e+01,  3.89766548973703e+00],
     [ 5.84649747456076e+00,  1.36418274016651e+01,  3.89766548973703e+00],
     [ 9.74416308122776e+00,  1.36418274016651e+01,  3.89766548973703e+00],
     [ 1.36418286878948e+01,  1.36418274016651e+01,  3.89766548973703e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 9.74416308122776e+00,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 1.36418286878948e+01,  1.94883058166410e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 9.74416308122776e+00,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 1.36418286878948e+01,  5.84649618833110e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 9.74416308122776e+00,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 1.36418286878948e+01,  9.74416179499810e+00,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  1.36418274016651e+01,  7.79533109640403e+00],
     [ 5.84649747456076e+00,  1.36418274016651e+01,  7.79533109640403e+00],
     [ 9.74416308122776e+00,  1.36418274016651e+01,  7.79533109640403e+00],
     [ 1.36418286878948e+01,  1.36418274016651e+01,  7.79533109640403e+00],
     [ 1.94883186789375e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 5.84649747456076e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 9.74416308122776e+00,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 1.36418286878948e+01,  1.94883058166410e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 5.84649747456076e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 9.74416308122776e+00,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 1.36418286878948e+01,  5.84649618833110e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 5.84649747456076e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 9.74416308122776e+00,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 1.36418286878948e+01,  9.74416179499810e+00,  1.16929967030710e+01],
     [ 1.94883186789375e+00,  1.36418274016651e+01,  1.16929967030710e+01],
     [ 5.84649747456076e+00,  1.36418274016651e+01,  1.16929967030710e+01],
     [ 9.74416308122776e+00,  1.36418274016651e+01,  1.16929967030710e+01],
     [ 1.36418286878948e+01,  1.36418274016651e+01,  1.16929967030710e+01]]




e=0
f=(np.array(r)*0).tolist()

z='38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 '+\
 '38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 '+\
 '38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 38 22 22 22 22 22 22 22 22 '+\
 '22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 '+\
 '22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 22 '+\
 '22 22 22 22 22 22 22 22  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 '+\
  '8  8  8  8  8  8  8  8'

z = [int(i) for i in z.split()]

E.append([e])
F.append(f)
R.append(r)
Z.append(z)

E=np.array(E)
F=np.array(F)
R=np.array(R)
z=np.array(z)

np.savez('EquilibriumStructures/4x4x4',E=E,F=F,R=R,z=z)
data=np.load('EquilibriumStructures/4x4x4.npz')

# %%
NN=Model.Model(PathToModel='nvt.1500.RS/',PathToData='EquilibriumStructures/4x4x4.npz',TestSetSize=1)

PredictedForces,PredictedEnergies,\
ActualForces,ActualEnergies \
=NN.PredictForcesAndEnergies()

plt.figure()
plt.plot(PredictedForces.flatten(),ActualForces.flatten()\
         ,'o',label='R2='+str(r2_score(ActualForces.flatten(),PredictedForces.flatten())))
plt.xlabel('predicted F (eV/Ang)')
plt.ylabel('actual F (eV/Ang)')
plt.legend()
